# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiagorcj/Metodos_Matematicos/blob/main/MM5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Métodos Matemáticos: Lista de Exercícios Séries Numéricas - Conceitos Iniciais
# ## Questão 1
# Partindo de uma função que defina o termo geral de uma sequência
# a(n), para n = n0, n0 + 1, n0 + 2, · · · , implemente um programa para
# ilustrar o comportamento da série numérica P∞
# n=n0
# a(n), com as duas
# opções exclusivas de execução:
#
# (a) o usuário sabe que a série é convergente para a soma S;
#
# (b) o usuário não sabe se a série é convergente.
#
# – Caso seja feita a escolha da opção (a), o usuário deve fornecer
# como entradas o valor da soma S, o valor de uma tolerância ϵ e dois
# ´ındices kmim ≥ n0 e kmax > kmim tal que |S(k) − S| ≤ ϵ, com
# S(k) = P
# k
# n=n0
# a(n), para todos índices k com k = kmim, kmim +
# 1, · · · , kmax (sugestão: considere 0 < kmax − kmim ≤ 20);
#
# – Caso seja feita a escolha da opção (b), o usuário deve fornecer
# apenas os dois índices kmim e kmax.
# O programa deve fornecer como saídas:
#
# (i) uma tabela mostrando as triplas (k, a(k), S(k)), para k = kmin, . . . , kmax;
#
# (ii) uma figura em que o eixo horizontal represente o intervalo [kmim, kmax]
# e mostrando os dois conjuntos de pontos (k, a(k)) e (k, S(k)) em
# cores distintas, de maneira discreta, para k = kmim, . . . , kmax;
#
# (iii) Caso o usuário escolha a opção (a), o programa deve acrescentar na figura do item (ii) os gráficos dos três segmentos de reta
# horizontais, respectivamente com alturas S − ϵ, S e S + ϵ.
# ## Resolução:
# Para ter uma série convergente escolhi o termo geral a(n) abaixo que converge para 2: $$a(n)= \frac{1}{2^n}$$

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def a(n):
  return (2/3)**n

def plot_horizontal_lines(S, epsilon, nmin, nmax):
    sns.scatterplot(x=ns, y=somas, color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico de Série numérica')

    # Adiciona as retas horizontais y = L - ϵ, y = L, y = L + ϵ
    plt.axhline(y=S - epsilon, color='red', linestyle='--', label='y = S - ϵ')
    plt.axhline(y=S, color='green', linestyle='--', label='y = L')
    plt.axhline(y=S + epsilon, color='blue', linestyle='--', label='y = S + ϵ')

    plt.legend()

    plt.show()

somas = []
ans = []
ns = []

while True:

  resposta = input("Escolha uma das alternativas a seguir(a,b ou c):\n a)Já sei o limite \n b)Não sei o limite\n c)Sair\n")

  #Caso o usuário escolha a letra c:
  if resposta == 'c':
    break;

  #Caso o usuário escolha a letra a:
  if resposta == 'b':
    nmin = int(input("Indique um número para ser o menor valor: "))
    nmax = int(input("Indique um número para ser o maior valor: "))

    lista = [a(n) for n in range(0,nmin)]
    soma = sum(lista)
    for n in range(nmin, nmax+1):
        ns.append(n)
        ans.append(a(n))
        soma += a(n)
        somas.append(soma)

    #Tabela:
    tabela = {'Valores de n' : ns, "Valores a(n)": ans, "Valores S": somas}
    tabela = pd.DataFrame(tabela)
    display(tabela)

    #Gráficos
    #Sequência
    sns.scatterplot(x=ns, y=ans,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de a(n)')
    plt.title('Gráfico de sequência númerica')
    plt.show()
    #Séries
    sns.scatterplot(x=ns, y=somas,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico da série númerica')
    plt.show()


  #Caso o usuário escolha letra a:
  if resposta == 'a':
    S = float(input("Digite o valor de S: "))
    epsilon = float(input("Digite o valor de ϵ: "))

    kmin = int(input('Digite o valor de kmin: '))
    kmax = int(input('Digite o valor de kmax: '))

    lista = [a(n) for n in range(0,kmin)]
    soma = sum(lista)
    for n in range(kmin,kmax):
      ns.append(n)
      soma += a(n)
      somas.append(soma)

    #Tabela:
    tabela = {'Valores de n' : ns, "Valores S(n)": somas}
    tabela = pd.DataFrame(tabela)
    display(tabela)
    plot_horizontal_lines(S, epsilon, kmin, kmax)

  else:
    print('Escolha inválida')
# Out:
#    Valores de n  Valores S(n)
# 0            19      2.999098
# 1            20      2.999399
# 2            21      2.999599
# 3            22      2.999733
# 4            23      2.999822
# 5            24      2.999881
# 6            25      2.999921
# 7            26      2.999947
# 8            27      2.999965
# 9            28      2.999977

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def a(n):
  return 2/n**(4/3)

def plot_horizontal_lines(S, epsilon, nmin, nmax):
    sns.scatterplot(x=ns, y=somas, color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico de Série numérica')

    # Adiciona as retas horizontais y = L - ϵ, y = L, y = L + ϵ
    plt.axhline(y=S - epsilon, color='red', linestyle='--', label='y = S - ϵ')
    plt.axhline(y=S, color='green', linestyle='--', label='y = L')
    plt.axhline(y=S + epsilon, color='blue', linestyle='--', label='y = S + ϵ')

    plt.legend()

    plt.show()


while True:

  resposta = input("Escolha uma das alternativas a seguir(a,b ou c):\n a)Já sei o limite \n b)Não sei o limite\n c)Sair\n")

  #Caso o usuário escolha a letra c:
  if resposta == 'c':
    break;

  #Caso o usuário escolha a letra a:
  if resposta == 'b':
    somas = []
    ans = []
    ns = []
    nmin = int(input("Indique um número para ser o menor valor: "))
    nmax = int(input("Indique um número para ser o maior valor: "))

    lista = [a(n) for n in range(3,nmin)]
    soma = sum(lista)
    for n in range(nmin, nmax+1):
        ns.append(n)
        ans.append(a(n))
        soma += a(n)
        somas.append(soma)

    #Tabela:
    tabela = {'Valores de n' : ns, "Valores a(n)": ans, "Valores S": somas}
    tabela = pd.DataFrame(tabela)
    display(tabela)

    #Gráficos
    #Sequência
    sns.scatterplot(x=ns, y=ans,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de a(n)')
    plt.title('Gráfico de sequência númerica')
    plt.show()
    #Séries
    sns.scatterplot(x=ns, y=somas,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico da série númerica')
    plt.show()


  #Caso o usuário escolha letra a:
  if resposta == 'a':
    somas = []
    ans = []
    ns = []
    S = float(input("Digite o valor de S: "))
    epsilon = float(input("Digite o valor de ϵ: "))

    kmin = int(input('Digite o valor de kmin: '))
    kmax = int(input('Digite o valor de kmax: '))

    lista = [a(n) for n in range(0,kmin)]
    soma = sum(lista)
    for n in range(kmin,kmax):
      ns.append(n)
      soma += a(n)
      somas.append(soma)

    #Tabela:
    tabela = {'Valores de n' : ns, "Valores S(n)": somas}
    tabela = pd.DataFrame(tabela)
    display(tabela)
    plot_horizontal_lines(S, epsilon, kmin, kmax)

  else:
    print('Escolha inválida')
# Out:
# Escolha uma das alternativas a seguir(a,b ou c):
#  a)Já sei o limite
#  b)Não sei o limite
#  c)Sair
# b
# Indique um número para ser o menor valor: 296
# Indique um número para ser o maior valor: 306
#     Valores de n  Valores a(n)  Valores S
# 0            296      0.001014   3.508381
# 1            297      0.001009   3.509391
# 2            298      0.001005   3.510395
# 3            299      0.001000   3.511396
# 4            300      0.000996   3.512392
# 5            301      0.000991   3.513383
# 6            302      0.000987   3.514370
# 7            303      0.000983   3.515353
# 8            304      0.000978   3.516331
# 9            305      0.000974   3.517305
# 10           306      0.000970   3.518275
# Escolha inválida
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6d43fe270c88> in <cell line: 25>()
#      25 while True:
#      26
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def a(n):
  return 1/(n*(3**n))

def plot_horizontal_lines(S, epsilon, nmin, nmax):
    sns.scatterplot(x=ns, y=somas, color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico de Série numérica')

    # Adiciona as retas horizontais y = L - ϵ, y = L, y = L + ϵ
    plt.axhline(y=S - epsilon, color='red', linestyle='--', label='y = S - ϵ')
    plt.axhline(y=S, color='green', linestyle='--', label='y = L')
    plt.axhline(y=S + epsilon, color='blue', linestyle='--', label='y = S + ϵ')

    plt.legend()

    plt.show()


while True:

  resposta = input("Escolha uma das alternativas a seguir(a,b ou c):\n a)Já sei o limite \n b)Não sei o limite\n c)Sair\n")

  #Caso o usuário escolha a letra c:
  if resposta == 'c':
    break;

  #Caso o usuário escolha a letra a:
  if resposta == 'b':
    somas = []
    ans = []
    ns = []
    menos_anterior = []  # Inicializa com [0] para ter pelo menos um elemento
    nmin = int(input("Indique um número para ser o menor valor: "))
    nmax = int(input("Indique um número para ser o maior valor: "))

    lista = [a(n) for n in range(1, nmin)]
    lista2 = [a(n) for n in range(1, nmin-1)]
    soma = sum(lista)
    soma2 = sum(lista2)
    print(lista)
    menos_anterior.append(soma - soma2)
    for n in range(nmin, nmax + 1):
        ns.append(n)
        ans.append(a(n))
        soma += a(n)
        somas.append(soma)

    for i in range(1, len(somas)):
        menos_anterior.append(somas[i] - somas[i - 1])

    # Tabela:
    tabela = {'Valores de n': ns, "Valores a(n)": ans, "Valores S": somas, "Valor S(k) - S(k-1)": menos_anterior}
    tabela = pd.DataFrame(tabela)
    display(tabela)
    #Gráficos
    #Sequência
    sns.scatterplot(x=ns, y=ans,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de a(n)')
    plt.title('Gráfico de sequência númerica')
    plt.show()
    #Séries
    sns.scatterplot(x=ns, y=somas,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico da série númerica')
    plt.show()


  #Caso o usuário escolha letra a:
  if resposta == 'a':
    somas = []
    ans = []
    ns = []
    S = float(input("Digite o valor de S: "))
    epsilon = float(input("Digite o valor de ϵ: "))

    kmin = int(input('Digite o valor de kmin: '))
    kmax = int(input('Digite o valor de kmax: '))

    lista = [a(n) for n in range(0,kmin)]
    soma = sum(lista)
    for n in range(kmin,kmax):
      ns.append(n)
      soma += a(n)
      somas.append(soma)

    #Tabela:
    tabela = {'Valores de n' : ns, "Valores S(n)": somas}
    tabela = pd.DataFrame(tabela)
    display(tabela)
    plot_horizontal_lines(S, epsilon, kmin, kmax)

  else:
    print('Escolha inválida')
# Out:
# [0.3333333333333333, 0.05555555555555555, 0.012345679012345678, 0.0030864197530864196, 0.0008230452674897119, 0.00022862368541380886, 6.532105297537396e-05]
#     Valores de n  Valores a(n)  Valores S  Valor S(k) - S(k-1)
# 0              8  1.905197e-05   0.405457         6.532105e-05
# 1              9  5.645029e-06   0.405463         5.645029e-06
# 2             10  1.693509e-06   0.405464         1.693509e-06
# 3             11  5.131845e-07   0.405465         5.131845e-07
# 4             12  1.568064e-07   0.405465         1.568064e-07
# 5             13  4.824811e-08   0.405465         4.824811e-08
# 6             14  1.493394e-08   0.405465         1.493394e-08
# 7             15  4.646115e-09   0.405465         4.646115e-09
# 8             16  1.451911e-09   0.405465         1.451911e-09
# 9             17  4.555014e-10   0.405465         4.555014e-10
# 10            18  1.433986e-10   0.405465         1.433986e-10
# Escolha inválida

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
def a(n):
  angulo_radianos = np.radians(n)
  return n/np.cos(angulo_radianos)

def plot_horizontal_lines(S, epsilon, nmin, nmax):
    sns.scatterplot(x=ns, y=somas, color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico de Série numérica')

    # Adiciona as retas horizontais y = L - ϵ, y = L, y = L + ϵ
    plt.axhline(y=S - epsilon, color='red', linestyle='--', label='y = S - ϵ')
    plt.axhline(y=S, color='green', linestyle='--', label='y = L')
    plt.axhline(y=S + epsilon, color='blue', linestyle='--', label='y = S + ϵ')

    plt.legend()

    plt.show()


while True:

  resposta = input("Escolha uma das alternativas a seguir(a,b ou c):\n a)Já sei o limite \n b)Não sei o limite\n c)Sair\n")

  #Caso o usuário escolha a letra c:
  if resposta == 'c':
    break;

  #Caso o usuário escolha a letra a:
  if resposta == 'b':
    somas = []
    ans = []
    ns = []
    nmin = int(input("Indique um número para ser o menor valor: "))
    nmax = int(input("Indique um número para ser o maior valor: "))

    lista = [a(n) for n in range(1,nmin)]
    soma = sum(lista)
    for n in range(nmin, nmax+1):
        ns.append(n)
        ans.append(a(n))
        soma += a(n)
        somas.append(soma)
  #Tabela:
    tabela = {'Valores de n' : ns, "Valores a(n)": ans, "Valores S(n)": somas}
    tabela = pd.DataFrame(tabela)
    display(tabela)

    #Gráficos
    #Sequência
    sns.scatterplot(x=ns, y=ans,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de a(n)')
    plt.title('Gráfico de sequência númerica')
    plt.show()
    #Séries
    sns.scatterplot(x=ns, y=somas,color='purple')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlabel('Valores de n')
    plt.ylabel('Valores de S(n)')
    plt.title('Gráfico da série númerica')
    plt.show()
# Out:
# Escolha uma das alternativas a seguir(a,b ou c):
#  a)Já sei o limite
#  b)Não sei o limite
#  c)Sair
# b
# Indique um número para ser o menor valor: 1
# Indique um número para ser o maior valor: 10
#    Valores de n  Valores a(n)  Valores S(n)
# 0             1      1.000152      1.000152
# 1             2      2.001219      3.001371
# 2             3      3.004117      6.005488
# 3             4      4.009768     10.015256
# 4             5      5.019099     15.034355
# 5             6      6.033050     21.067405
# 6             7      7.052569     28.119974
# 7             8      8.078621     36.198594
# 8             9      9.112186     45.310780
# 9            10     10.154266     55.465047
# Escolha uma das alternativas a seguir(a,b ou c):
#  a)Já sei o limite
#  b)Não sei o limite
#  c)Sair
# c

# %%
import math

# Calcular k
k = math.log(0.0003333333, 2/3) +1

print("O valor de k é aproximadamente:", k)
# Out:
# O valor de k é aproximadamente: 20.74613229978453
